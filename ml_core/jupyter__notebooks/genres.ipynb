# %%
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
import os
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
music_list = pd.read_csv('url_list.csv')

# %%
movies = set(music_list['Film'])
print(len(movies))
# Out:
# 153

# %%
print(music_list['Genres'])
# Out:
# 0                 Action, Drama
# 1                 Action, Drama
# 2             Adventure, Sci-Fi
# 3             Adventure, Sci-Fi
# 4             Adventure, Sci-Fi
#                  ...
# 219                  Drama, War
# 220      Action, Horror, Sci-Fi
# 221                Drama, Music
# 222    Family, Fantasy, Musical
# 223     Action, Drama, Thriller
# Name: Genres, Length: 224, dtype: object

# %%
gnrs = list(music_list['Genres'])

# %%
gnrs_all = ', '.join(gnrs)

# %%
gnrs_list = gnrs_all.split(", ")

# %%
import seaborn as sns


sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set(style="whitegrid")
sns.set_context("poster")
ax = sns.countplot(y=gnrs_list, color="blue")
plt.xlim(0, 140)
# Out:
# (0, 140)
